# %% [markdown]
# <a href="https://colab.research.google.com/github/Arya0307/Data_Analysis/blob/main/Data_Analysis_on_Police_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Analysis on Police Dataset**

# %%
import pandas as pd
Data=pd.read_csv("/content/Project - 2 (Police Dataset) PANDAS.csv")
Data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# **Q1-Remove the column that only contains missing value.**

# %%
Data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          44919
# driver_gender          2819
# driver_age_raw         2811
# driver_age             3039
# driver_race            2818
# violation_raw          2818
# violation              2819
# search_conducted          1
# search_type           43118
# stop_outcome           2819
# is_arrested            2819
# stop_duration          2819
# drugs_related_stop        1
# dtype: int64

# %%
Data.drop(columns="country_name",inplace=True)
Data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 44914  9/10/2010     19:15             M          1981.0        29.0
# 44915  9/10/2010     19:21             F          1986.0        24.0
# 44916  9/10/2010     19:37             F          1987.0        23.0
# 44917  9/10/2010     19:40           NaN             NaN         NaN
# 44918  9/10/2010     20:26             M          1985.0        25.0
#
#       driver_race                   violation_raw  violation search_conducted  \
# ...

# %% [markdown]
# **Q2-For Speeding, where men or women stopped?**

# %%
Data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding            False         NaN     Citation
# 1      Speeding  Speeding            False         NaN     Citation
#
#   is_arrested stop_duration drugs_related_stop
# 0       False      0-15 Min              False
# 1       False      0-15 Min              False

# %%
Data[Data.violation=="Speeding"].driver_gender.value_counts()
# Out:
# M    19666
# F     8655
# Name: driver_gender, dtype: int64

# %% [markdown]
# **Q3-Does gender affect who gets searched during a stop?**

# %%
Data.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     267
# M    1534
# Name: search_conducted, dtype: object

# %%
Data.search_conducted.value_counts()
# Out:
# False    43117
# True      1801
# Name: search_conducted, dtype: int64

# %% [markdown]
# **Q4-What is the mean stop_duration?**

# %%
Data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
Data.stop_duration.value_counts()
# Out:
# 0-15 Min     31812
# 16-30 Min     8388
# 30+ Min       1900
# Name: stop_duration, dtype: int64

# %%
Data['stop_duration']=Data['stop_duration'].map({'0-15 Min':7.5,'16-30 Min':24, '30+ Min':45 } )
Data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
Data["stop_duration"].mean()
# Out:
# 12.187420698181345

# %% [markdown]
# **Q5-Compare the age distributions for each violation**

# %%
Data.groupby('violation').driver_age_raw.describe()
# Out:
#                        count         mean         std     min     25%     50%  \
# violation
# Equipment             6515.0  1975.935380   65.818854     0.0  1971.0  1981.0
# Moving violation     11926.0  1965.462770  120.359733     0.0  1963.0  1974.0
# Other                 3583.0  1912.442088  329.302162     0.0  1959.0  1968.0
# Registration/plates   2243.0  1973.686135   73.103745     0.0  1969.0  1979.0
# Seat belt                3.0  1981.666667   10.214369  1970.0  1978.0  1986.0
# Speeding             37204.0  1972.189711   86.672468     0.0  1966.0  1979.0
#
#                         75%     max
# violation
# Equipment            1987.0  2005.0
# Moving violation     1984.0  2006.0
# Other                1979.0  2011.0
# Registration/plates  1985.0  1996.0
# Seat belt            1987.5  1989.0
# Speeding             1985.0  8801.0
